# %% [markdown]
# # 1- Introduction

# %% [markdown]
# ## 1.1 Problem statement

# %% [markdown]
# Twitter has become an important communication channel in times of emergency.
# The ubiquitousness of smartphones enables people to announce an emergency they’re observing in real-time. Because of this, more agencies are interested in programatically monitoring Twitter (i.e. disaster relief organizations and news agencies).
#
# But, it’s not always clear whether a person’s words are actually announcing a disaster.
#
# THe challenge is to build an NLP model to predict whether a Tweet is actually describing real emergency or not

# %% [markdown]
# ## 1.2 Load the packages

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords 


import torch
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS

# %matplotlib inline

# Check if we have CUDA
print("CUDA device(s): " + str(torch.cuda.device_count()))
# Out:
# CUDA device(s): 0

# %% [markdown]
# ## 1.3 Load the data

# %%
sample_submission = pd.read_csv("data/sample_submission.csv")
test = pd.read_csv("data/test.csv")
train = pd.read_csv("data/train.csv")

# %% [markdown]
# # 2. Preprocessing and EDA

# %%
print("Train data shape: " + str(train.shape))
print("Test data shape: " + str(test.shape))
print("Test/Train ratio: " +str(np.round(test.shape[0]/train.shape[0]*100, 2)) + "%")
# Out:
# Train data shape: (7613, 5)
# Test data shape: (3263, 4)
# Test/Train ratio: 42.86%

# %% [markdown]
# Ok, we have 7.6k rows of training data, and 3.2k rows of test data (~40% the size of the train data)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
# id          7613 non-null int64
# keyword     7552 non-null object
# location    5080 non-null object
# text        7613 non-null object
# target      7613 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB

# %% [markdown]
# Ok, so the `id` and `target` columns in the training dataset are good, no NULL values there, of course. Let's have a look at the other 3 columns.

# %%
train.describe(include='object')
# Out:
#            keyword location                                               text
# count         7552     5080                                               7613
# unique         221     3341                                               7503
# top     fatalities      USA  11-Year-Old Boy Charged With Manslaughter of T...
# freq            45      104                                                 10

# %%
train.keyword.value_counts().reset_index().rename(columns={'keyword':'N'})
# Out:
#                      index   N
# 0               fatalities  45
# 1               armageddon  42
# 2                   deluge  42
# 3                  sinking  41
# 4                     harm  41
# ..                     ...  ..
# 216          forest%20fire  19
# 217              epicentre  12
# 218                 threat  11
# 219             inundation  10
# 220  radiation%20emergency   9
#
# [221 rows x 2 columns]

# %%
text = ' '.join(train.keyword.dropna().values).replace("%20", "_")
wordcloud = WordCloud(
    width = 500,
    height = 300,
    background_color = 'black',
    collocations=False,
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (10, 5),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
train.location.value_counts().reset_index().rename(columns={'location':'N'})
# Out:
#                        index    N
# 0                        USA  104
# 1                   New York   71
# 2              United States   50
# 3                     London   45
# 4                     Canada   29
# ...                      ...  ...
# 3336         LA - everywhere    1
# 3337           brooklyn, NYC    1
# 3338   Washington, DC NATIVE    1
# 3339  In a crazy genius mind    1
# 3340  SaudI arabia - riyadh     1
#
# [3341 rows x 2 columns]

# %%
text = ' '.join(train.location.dropna().str.strip().replace(' ', "_").values).replace("%20", "_")
wordcloud = WordCloud(
    width = 500,
    height = 300,
    background_color = 'black',
    collocations=False,
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (10, 5),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# Count if we have any retweets

# %%
temp = train.text.value_counts().reset_index()
temp = temp[temp.text > 1]
print(str(temp.shape[0]) + " unique texts - " + str(temp.text.sum()) + " tweets - " + str(np.round(temp.text.sum()/train.shape[0]*100, 2)) + "% of train data")
# Out:
# 69 unique texts - 179 tweets - 2.35% of train data

# %% [markdown]
# ## 2.1 Check to see if there are any big differences in disaster tweets and non-disaster tweets

# %%
list(set(train[train.target == 1].text.values))[:10]
# Out:
# ['just in: #kenya: several buildings are reported to be on fire close to dam estate #langata at 2:22pm.',
#  'Rly tragedy in MP: Some live to recount horror: \x89ÛÏWhen I saw coaches of my train plunging into water I called ... http://t.co/0Xh758OnUP',
#  "@TrillAC_ I think we've only had like one black mass murderer in the history of mass murders white people do that shit.",
#  '#Politics Democracy\x89Ûªs hatred for hate: \x89Û_ Dawabsha threaten to erode Israeli democracy. Homegrown terrorism ha...  http://t.co/q8n5Tn8WME',
#  'Rare insight into #terror and How to fight it http://t.co/t6OBVWaPhW #Cameroon #USA #Whitehouse #ES #FR #Nigeria #UK #Africa #DE #CA #AU #JP',
#  'Malaysia PM confirms wreckage belongs to MH370 http://t.co/kacrlpjC0l http://t.co/YjJbNTcaZY',
#  'DTN Italy: Families to sue over Legionnaires: More than 40 families affected by the fatal outbreak of Legionna... http://t.co/RsV9ATj9vH',
#  'Second tornado confirmed in Sunday\x89Ûªs storm http://t.co/Ffnzit7kgN',
#  '13 security personnel killed in Iraq suicide bombing | http://t.co/IbAZRHlSUr http://t.co/B6wWq2nYQI',
#  'Mad River Complex fires have burned 14028 acres 8% contained: The Mad River Complex fires in Trinity County ... http://t.co/LfNIPpNOtO']

# %%
list(set(train[train.target == 0].text.values))[:10]
# Out:
# ['There is this old lady rockin out to death metal in her sedan downtown smoking a cigarette. I found my real mom.',
#  '@Silverhusky Shtap!  Before your town is obliterated and the earth is salted T_T',
#  'Alhaji Putin is far from being a good person sha. At least I had front row seat to his complete obliteration of Ibeto cement a competitor.',
#  'Amazon Deal - wait or buy? http://t.co/0T8VqKEArI',
#  'Max blew tf up ! ?????? shots fired ???? #CatfishMTV',
#  'Epicentre - Cydia Tweak - https://t.co/WKmfDig3nT | Thanks to @phillipten.',
#  "@lizbon @KidicalMassDC It's more of a structural breakdown. Or maybe a patience failure on their part.",
#  'White Twister Black shift knob M6x1.00 Thread Size http://t.co/SqpshAWs0w http://t.co/udlEbH88uZ',
#  "Was '80s New #Wave a #Casualty of #AIDS?: Tweet And Since they\x89Ûªd grown up watching David\x89Û_ http://t.co/qBecjli7cx",
#  "'NO LENDER FEES FOR VETERANS OR FIRST RESPONDERS (PAST AND PRESENT)' on @LinkedIn https://t.co/9pmBTxmoAL"]

# %% [markdown]
# ### 2.1.2 Check tweet length

# %%
train['nchar'] = [len(t) for t in train.text.values]
print(train.nchar.describe())
print(train[train.target == 0].nchar.describe())
print(train[train.target == 1].nchar.describe())
sns.distplot(train[train.target == 0][['nchar']], hist=False, rug=True)
sns.distplot(train[train.target == 1][['nchar']], hist=False, rug=True)
plt.legend(['Non-disaster', 'Disaster'])
plt.show()
# Out:
# count    7613.000000
# mean      101.037436
# std        33.781325
# min         7.000000
# 25%        78.000000
# 50%       107.000000
# 75%       133.000000
# max       157.000000
# Name: nchar, dtype: float64
# count    4342.000000
# mean       95.706817
# std        35.885924
# min         7.000000
# 25%        68.000000
# 50%       101.000000
# 75%       130.000000
# max       157.000000
# Name: nchar, dtype: float64
# count    3271.000000
# mean      108.113421
# std        29.309854
# min        14.000000
# 25%        88.000000
# 50%       115.000000
# 75%       136.000000
# max       151.000000
# Name: nchar, dtype: float64

# %% [markdown]
# We can see that Disaster tweets tend to be longer than Non-disaster tweets. There are also some tweets with more than 140 characters, this is because of the use of emojis.

# %%
def clean_text(text):
    #Emoji patterns
    emoji_pattern = re.compile("["
             u"\U0001F600-\U0001F64F"  # emoticons
             u"\U0001F300-\U0001F5FF"  # symbols & pictographs
             u"\U0001F680-\U0001F6FF"  # transport & map symbols
             u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
             u"\U00002702-\U000027B0"
             u"\U000024C2-\U0001F251"
             "]+", flags=re.UNICODE)
    text = emoji_pattern.sub('', text)
    
    #Emoticons
    #HappyEmoticons
    emoticons_happy = set([
        ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
        ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
        '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
        'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
        '<3'
        ])
    # Sad Emoticons
    emoticons_sad = set([
        ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
        ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
        ':c', ':{', '>:\\', ';('
        ])
    emoticons = emoticons_happy.union(emoticons_sad)
    
    #removing mentions
    text = re.sub(r':', '', text)
    text = re.sub(r'‚Ä¶', '', text)
    #replace consecutive non-ASCII characters with a space
    text = re.sub(r'[^\x00-\x7F]+',' ', text)#remove emojis from tweet
    text = emoji_pattern.sub(r'', text)
    
    return preprocessing.clean(text)

train['text_clean'] = [give_emoji_free_text(t) for t in train.text]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-f853c93156a2> in <module>
#      37     return preprocessing.clean(text)
#      38
# ---> 39 train['text_clean'] = [give_emoji_free_text(t) for t in train.text]
#
# <ipython-input-14-f853c93156a2> in <listcomp>(.0)
#      37     return preprocessing.clean(text)
#      38
# ---> 39 train['text_clean'] = [give_emoji_free_text(t) for t in train.text]
#
# NameError: name 'give_emoji_free_text' is not defined

# %%
train[['text', 'text_clean']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-b6bb9ab8e470> in <module>
# ----> 1 train[['text', 'text_clean']]
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2999             if is_iterator(key):
#    3000                 key = list(key)
# -> 3001             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    3002
#    3003         # take() does not accept boolean indexers
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "['text_clean'] not in index"

# %%
print(list(set(train[train.target == 0].text.values))[100:110])
print()
print(list(set(train[train.target == 0].text_clean.values))[100:110])
# Out:
# ['#BakeOffFriends the one with the mudslide', 'I got evacuated from the cinema 30 mins through Inside Out\nKill me please', 'Panic! at the Disco is the best song by this is gospel (acoustic) http://t.co/VCq2icptKI', "12' 72W CREE LED Work Light Bar Alloy Spot Flood Combo Diving Offroad 4WD Boat - Full read\x89Û_ http://t.co/MJMwA72ER6 http://t.co/ADx9iYi246", 'Isai 60:1; Psm 138:8\n Every conspiracy against my lifting be scattered unto desolation in the name o f Jesus.', "FollowNFLNews: Michael Floyd's hand injury shouldn't devalue his fantasy stock http://t.co/5dUjGypImA #NFL #News #Playoffs", 'Video Captures Man Removing American Flag From Long Beach CA Home Burning It; Arsonist Sought http://t.co/JP2QlrunjJ http://t.co/jbpgkGOwSi', "We're #hiring! Read about our latest #job opening here: Registered Nurse - Call-in - Military Program - http://t.co/l0hhwB9LSZ #Nursing", "witnessed my very first demolition derby today psa that my excitement has not worn down and it's been over 3 hours", 'Ignition Knock (Detonation) Sensor ACDelco GM Original Equipment 213-4678 http://t.co/O2jD4TbrwA http://t.co/JFx6qiyiVF']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-9cde6ada26a9> in <module>
#       1 print(list(set(train[train.target == 0].text.values))[100:110])
#       2 print()
# ----> 3 print(list(set(train[train.target == 0].text_clean.values))[100:110])
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'text_clean'

# %%
list(set(train[train.target == 0].text.values))[100:110]
# Out:
# ['#BakeOffFriends the one with the mudslide',
#  'I got evacuated from the cinema 30 mins through Inside Out\nKill me please',
#  'Panic! at the Disco is the best song by this is gospel (acoustic) http://t.co/VCq2icptKI',
#  "12' 72W CREE LED Work Light Bar Alloy Spot Flood Combo Diving Offroad 4WD Boat - Full read\x89Û_ http://t.co/MJMwA72ER6 http://t.co/ADx9iYi246",
#  'Isai 60:1; Psm 138:8\n Every conspiracy against my lifting be scattered unto desolation in the name o f Jesus.',
#  "FollowNFLNews: Michael Floyd's hand injury shouldn't devalue his fantasy stock http://t.co/5dUjGypImA #NFL #News #Playoffs",
#  'Video Captures Man Removing American Flag From Long Beach CA Home Burning It; Arsonist Sought http://t.co/JP2QlrunjJ http://t.co/jbpgkGOwSi',
#  "We're #hiring! Read about our latest #job opening here: Registered Nurse - Call-in - Military Program - http://t.co/l0hhwB9LSZ #Nursing",
#  "witnessed my very first demolition derby today psa that my excitement has not worn down and it's been over 3 hours",
#  'Ignition Knock (Detonation) Sensor ACDelco GM Original Equipment 213-4678 http://t.co/O2jD4TbrwA http://t.co/JFx6qiyiVF']

# %%
sid = SentimentIntensityAnalyzer()

train['sid'] = [sid.polarity_scores(t) for t in train.text_clean.values]
train['compound'] = [d['compound'] for d in train.sid.values]
train.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-63b6b67ec699> in <module>
#       1 sid = SentimentIntensityAnalyzer()
#       2
# ----> 3 train['sid'] = [sid.polarity_scores(t) for t in train.text_clean.values]
#       4 train['compound'] = [d['compound'] for d in train.sid.values]
#       5 train.head()
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'text_clean'

# %%
print(train.groupby('target').compound.mean())
print(train.groupby('target').compound.min())
print(train.groupby('target').compound.max())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-478c6fc83d97> in <module>
# ----> 1 print(train.groupby('target').compound.mean())
#       2 print(train.groupby('target').compound.min())
#       3 print(train.groupby('target').compound.max())
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     561             return self[attr]
#     562         if hasattr(self.obj, attr):
# --> 563             return self._make_wrapper(attr)
#     564
#     565         raise AttributeError(
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     602                 "using the 'apply' method".format(kind, name, type(self).__name__)
#     603             )
# --> 604             raise AttributeError(msg)
#     605
#     606         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'compound' of 'DataFrameGroupBy' objects, try using the 'apply' method
